# %% [markdown]
# # Mean Squared Error (MSE)
#
# $$
# \mathrm{MSE} \;=\; \frac{1}{n}\sum_{i=1}^{n}(y_i - \hat y_i)^{2},
# \quad
# \hat y_i \;=\; m\,x_i + b
# $$
#
# ---
#
# ## Gradients
#
# **Gradient w.r.t. m**
#
# $$
# \frac{\partial\,\mathrm{MSE}}{\partial m}
# =
# -\;\frac{2}{n}\sum_{i=1}^{n}x_i\,(y_i - \hat y_i)
# =
# \frac{2}{n}\sum_{i=1}^{n}(\hat y_i - y_i)\,x_i
# $$
#
# **Gradient w.r.t. b**
#
# $$
# \frac{\partial\,\mathrm{MSE}}{\partial b}
# =
# -\;\frac{2}{n}\sum_{i=1}^{n}(y_i - \hat y_i)
# =
# \frac{2}{n}\sum_{i=1}^{n}(\hat y_i - y_i)
# $$

# %%
import numpy as np


def gradient_descent(x,y, lr=0.1 , epochs=100):
    
    m, b = 0.0, 0.0
    

    
    for epoch in range(epochs):
        y_pred = m*x + b
        error = (y- y_pred)
        cost = np.mean(error**2)
        
        dm = -2*np.mean(error*x)
        db = -2*np.mean(error)
        
        
        b -= db*lr
        m -= dm*lr
        print(f"m={m} , b={b} ,Epoch {epoch}: Cost= {cost}")

# %%
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])
    
gradient_descent(x,y)
# Out:
# m=6.2 , b=1.8 ,Epoch 0: Cost= 89.0
# m=-2.320000000000001 , b=-0.4800000000000002 ,Epoch 1: Cost= 165.24
# m=9.272000000000002 , b=2.8080000000000007 ,Epoch 2: Cost= 307.59840000000014
# m=-6.611200000000004 , b=-1.5168000000000008 ,Epoch 3: Cost= 573.3613440000004
# m=15.043520000000008 , b=4.553280000000003 ,Epoch 4: Cost= 1069.452311040001
# m=-14.584192000000009 , b=-3.583488000000001 ,Epoch 5: Cost= 1995.4416651264023
# m=25.851123200000018 , b=7.683724800000004 ,Epoch 6: Cost= 3723.822955597828
# m=-29.43158272000003 , b=-7.563694080000008 ,Epoch 7: Cost= 6949.846718357678
# m=46.05611571200004 , b=13.407994368000011 ,Epoch 8: Cost= 12971.181693567845
# m=-57.112135475200056 , b=-15.10727393280002 ,Epoch 9: Cost= 24209.895819923546
# m=83.79892692992007 , b=23.98146213888002 ,Epoch 10: Cost= 45186.72131291331
# m=-108.74758959923213 , b=-29.29418644684803 ,Epoch 11: Cost= 84339.49719952248
# m=154.27361938718735 , b=43.61320460206085 ,Epoch 12: Cost= 157417.24894304285
# m=-205.09626602586133 , b=-55.87360795066374 ,Epoch 13: Cost= 293815.15712007193
# m=285.83968400143186 , b=80.15887325498579 ,Epoch 14: Cost= 548398.6253778435
# m=-384.9029447547097 , b=-105.57671179687046 ,Epoch 15: Cost= 1023572.6212919488
# m=531.4295607837741 , b=148.28039741532947 ,Epoch 16: Cost= 1910473.574759102
# m=-720.4837113897267 , b=-198.4334185380009 ,Epoch 17: Cost= 3565853.073986396
# m=989.8405047904728 , b=275.34349200343524 ,Epoch 18: Cost= 6655579.450501649
# m=-1346.8147009506285 , b=-371.8295092715356 ,Epoch 19: Cost= 12422480.065290723
# m=1845.475346703675 , b=512.4252131531487 ,Epoch 20: Cost= 23186262.54825995
# m=-2515.8255439362983 , b=-695.545037499686 ,Epoch 21: Cost= 43276605.869365275
# m=3442.517675223369 , b=954.8592963620301 ,Epoch 22: Cost= 80774752.57013461
# m=-4697.73678808526 , b=-1299.8231680443976 ,Epoch 23: Cost= 150764149.12959486
# m=6423.378046528951 , b=1780.5835384156383 ,Epoch 24: Cost= 281397688.684663
# m=-1237507696.087397 , b=-342769786.1411483 ,Epoch 63: Cost= 1.0451915476787206e+19
# m=1690671113.1895661 , b=468288790.53951955 ,Epoch 64: Cost= 1.9508250975832908e+19
# m=-2309778603.951192 , b=-639771633.6821239 ,Epoch 65: Cost= 3.641168520557814e+19
# m=3155597311.1507044 , b=874049857.2250161 ,Epoch 66: Cost= 6.796154207532755e+19
# m=-4311146681.515857 , b=-1194118499.11041 ,Epoch 67: Cost= 1.2684859750871776e+20
# m=5889847123.485274 , b=1631393211.4211862 ,Epoch 68: Cost= 2.367598821123592e+20
# m=-8046652468.835042 , b=-2228793703.154215 ,Epoch 69: Cost= 4.4190667361541574e+20
# m=10993259190.69458 , b=3044956520.577654 ,Epoch 70: Cost= 8.248082675305896e+20
# m=-15018884934.980087 , b=-4159990296.154625 ,Epoch 71: Cost= 1.5394849609781504e+21
# m=20518656105.868874 , b=5683338725.864353 ,Epoch 72: Cost= 2.873411965393521e+21
# m=-28032390556.361267 , b=-7764522681.029842 ,Epoch 73: Cost= 5.363154907093528e+21
# m=38297582282.45143 , b=10607816190.792889 ,Epoch 74: Cost= 1.0010200731360216e+22
# m=-52321788447.21745 , b=-14492296415.036549 ,Epoch 75: Cost= 1.8683800937688837e+22
# m=71481523991.88289 , b=19799235938.101234 ,Epoch 76: Cost= 3.487286887120671e+22
# m=-97657370346.92021 , b=-27049525642.848747 ,Epoch 77: Cost= 6.508937808554978e+22
# m=133418559808.21349 , b=36954801695.673134 ,Epoch 78: Cost= 1.2148777191834882e+23
# m=-182275152781.06006 , b=-50487294526.58959 ,Epoch 79: Cost= 2.2675402899511464e+23
# m=249022560059.42578 , b=68975256049.16437 ,Epoch 80: Cost= 4.232309873957901e+23
# m=-340212225694.6096 , b=-94233331194.52396 ,Epoch 81: Cost= 7.899505445871241e+23
# m=464794669556.4459 , b=128740670462.94662 ,Epoch 82: Cost= 1.4744238524055236e+24
# m=-634998005739.3031 , b=-175884265361.7103 ,Epoch 83: Cost= 2.751976957846861e+24
# m=867528166110.3903 , b=240291391156.01364 ,Epoch 84: Cost= 5.136499361539828e+24
# m=-1185208634019.8765 , b=-328283786739.6233 ,Epoch 85: Cost= 9.587153560959152e+24
# m=1619220632873.8262 , b=448498151022.02734 ,Epoch 86: Cost= 1.7894193483138623e+25
# m=-2212163650055.6074 , b=-612733858904.8739 ,Epoch 87: Cost= 3.339908538817294e+25
# m=3022236695415.8535 , b=837111102911.2657 ,Epoch 88: Cost= 6.233859636186344e+25
# m=-4128950696239.584 , b=-1143653134918.6997 ,Epoch 89: Cost= 1.1635350343286517e+26
# m=5640932716444.922 , b=1562447909810.5913 ,Epoch 90: Cost= 2.1717103931111163e+26
# m=-7706588005614.0625 , b=-2134601302016.6802 ,Epoch 91: Cost= 4.0534456568968845e+26
# m=10528666387953.082 , b=2916271761756.893 ,Epoch 92: Cost= 7.565659650354467e+26
# m=-14384162722591.637 , b=-3984182423364.5347 ,Epoch 93: Cost= 1.4121123308415373e+27
# m=19651504721134.883 , b=5443151694865.154 ,Epoch 94: Cost= 2.6356739888785434e+27
# m=-26847696682274.75 , b=-7436381476787.006 ,Epoch 95: Cost= 4.919422643601624e+27
# m=36679064904808.1 , b=10159512827937.045 ,Epoch 96: Cost= 9.181985043862575e+27
# m=-50110585582525.74 , b=-13879828680533.424 ,Epoch 97: Cost= 1.7137956108603738e+28
# m=68460599907357.13 , b=18962488405090.508 ,Epoch 98: Cost= 3.1987586363664317e+28
# m=-93530212931876.69 , b=-25906369220340.086 ,Epoch 99: Cost= 5.970406709462891e+28
